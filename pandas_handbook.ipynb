# %% [markdown]
# # Pandas Hadnbook

# %% [markdown]
# ## Importing modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# """To import a module use keyword import and module name. The name after as is a reference to the module.
# You can import the hole whole module or single parts of it with from module_name import function, var etc."""

# %%
from math import inf
a = inf
print(a)
# Out:
# inf

# %%
pd.__version__
# Out:
# '1.4.2'

# %% [markdown]
# # Loading Data

# %%
data = pd.read_csv(r'movies.csv', engine='python')

# %%
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# """
# Most common use is read_csv and read_excel.
# Mosty you will use this raw format of the function but there are ser='symbol' separator used for data stored in one column.
# Encoding by default utf-8 but in some special cases you might need other.
# data.head() cuts the data and gets oly the first 4
# """

# %% [markdown]
# # Selection

# %%
data.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %% [markdown]
# """Selection single column"""

# %%
data.name
# Out:
# 0                                          The Shining
# 1                                      The Blue Lagoon
# 2       Star Wars: Episode V - The Empire Strikes Back
# 3                                            Airplane!
# 4                                           Caddyshack
#                              ...
# 7663                                      More to Life
# 7664                                       Dream Round
# 7665                                     Saving Mbango
# 7666                                      It's Just Us
# 7667                                         Tee em el
# Name: name, Length: 7668, dtype: object

# %%
data['name']
# Out:
# 0                                          The Shining
# 1                                      The Blue Lagoon
# 2       Star Wars: Episode V - The Empire Strikes Back
# 3                                            Airplane!
# 4                                           Caddyshack
#                              ...
# 7663                                      More to Life
# 7664                                       Dream Round
# 7665                                     Saving Mbango
# 7666                                      It's Just Us
# 7667                                         Tee em el
# Name: name, Length: 7668, dtype: object

# %% [markdown]
# """Selectiong multiple columns"""

# %%
data[['name','year']]
# Out:
#                                                 name  year
# 0                                        The Shining  1980
# 1                                    The Blue Lagoon  1980
# 2     Star Wars: Episode V - The Empire Strikes Back  1980
# 3                                          Airplane!  1980
# 4                                         Caddyshack  1980
# ...                                              ...   ...
# 7663                                    More to Life  2020
# 7664                                     Dream Round  2020
# 7665                                   Saving Mbango  2020
# 7666                                    It's Just Us  2020
# 7667                                       Tee em el  2020
#
# [7668 rows x 2 columns]

# %% [markdown]
# """data.columns returns a list and all python list functions work over it"""

# %%
data[data.columns[2:4]]
# Out:
#           genre  year
# 0         Drama  1980
# 1     Adventure  1980
# 2        Action  1980
# 3        Comedy  1980
# 4        Comedy  1980
# ...         ...   ...
# 7663      Drama  2020
# 7664     Comedy  2020
# 7665      Drama  2020
# 7666      Drama  2020
# 7667     Horror  2020
#
# [7668 rows x 2 columns]

# %%
"""Last column"""
data[data.columns[-1]]
# Out:
# 0       146.0
# 1       104.0
# 2       124.0
# 3        88.0
# 4        98.0
#         ...
# 7663     90.0
# 7664     90.0
# 7665      NaN
# 7666    120.0
# 7667    102.0
# Name: runtime, Length: 7668, dtype: float64

# %% [markdown]
# # loc vs iloc

# %% [markdown]
# """
# loc[row, column] used to get rows and or columns by their label
# iloc[row, column] used to get rows and columns by their position
# """

# %%
data.loc[1,'genre']
# Out:
# 'Adventure'

# %%
data.iloc[1,2]
# Out:
# 'Adventure'

# %% [markdown]
# """As you can see in the first case i have to know the nama(label) of the column in the second the position of the column"""

# %%
data.iloc[1:5,1:3]
# Out:
#   rating      genre
# 1      R  Adventure
# 2     PG     Action
# 3     PG     Comedy
# 4      R     Comedy

# %%
data.loc[1:5,['rating','genre']]
# Out:
#   rating      genre
# 1      R  Adventure
# 2     PG     Action
# 3     PG     Comedy
# 4      R     Comedy
# 5      R     Horror

# %% [markdown]
# # Boolean indexing

# %%
data[data.score>=4]
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7658                       Black Wall Street Burning      R      Drama  2020
# 7660                                Aloha Surf Hotel    NaN     Comedy  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
data[data.score<=4]
# Out:
#                        name     rating      genre  year  \
# 80                   Phobia          R      Drama  1980
# 120      Tarzan the Ape Man   Approved  Adventure  1981
# 190                  Inchon         PG      Drama  1981
# 198                  Scream          R     Horror  1981
# 256               Megaforce         PG     Action  1982
# ...                     ...        ...        ...   ...
# 7595  Student of the Year 2  Not Rated     Action  2019
# 7616        High on the Hog          R     Action  2019
# 7640              El Coyote          R     Action  2019
# 7659              I Am Fear  Not Rated     Horror  2020
# 7663           More to Life        NaN      Drama  2020
#
#                                 released  score    votes           director  \
# 80     September 9, 1980 (United States)    4.0    546.0        John Huston
# 120        July 24, 1981 (United States)    3.4   5300.0         John Derek
# ...

# %%
data[data.score<=4].score.count()
# Out:
# 149

# %%
data[data.gross.isna()]
# Out:
#                       name rating      genre  year  \
# 27       Raise the Titanic     PG     Action  1980
# 41          Breaker Morant     PG      Drama  1980
# 47          The Boogey Man      R     Horror  1980
# 49      Lion of the Desert     PG  Biography  1980
# 52    Can't Stop the Music     PG  Biography  1980
# ...                    ...    ...        ...   ...
# 7663          More to Life    NaN      Drama  2020
# 7664           Dream Round    NaN     Comedy  2020
# 7665         Saving Mbango    NaN      Drama  2020
# 7666          It's Just Us    NaN      Drama  2020
# 7667             Tee em el    NaN     Horror  2020
#
#                               released  score    votes         director  \
# 27      August 1, 1980 (United States)    5.0   4100.0    Jerry Jameson
# 41            July 3, 1980 (Australia)    7.9  13000.0  Bruce Beresford
# 47    November 7, 1980 (United States)    4.6   3900.0      Ulli Lommel
# ...

# %%
data[data.gross.notna()]
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7653                                      The Quarry          R      Crime
# 7655                           Legend of Deification      TV-PG  Animation
# 7656                                           Tulsa      PG-13     Comedy
# 7657                                            Leap        NaN      Drama
# 7659                                       I Am Fear  Not Rated     Horror
#
#       year                            released  score      votes  \
# ...

# %%
data.groupby('rating').agg({'budget':'sum'})
# Out:
#                  budget
# rating
# Approved   6.500000e+06
# G          5.916570e+09
# NC-17      1.207500e+08
# Not Rated  3.812042e+08
# PG         4.013572e+10
# PG-13      8.829308e+10
# R          6.054087e+10
# TV-14      0.000000e+00
# TV-MA      5.400000e+07
# TV-PG      0.000000e+00
# Unrated    5.996377e+07
# X          1.700000e+07

# %%
data.groupby('rating').count()
# Out:
#            name  genre  year  released  score  votes  director  writer  star  \
# rating
# Approved      1      1     1         1      1      1         1       1     1
# G           153    153   153       153    153    153       153     153   153
# NC-17        23     23    23        23     23     23        23      23    23
# Not Rated   283    283   283       283    283    283       283     282   283
# PG         1252   1252  1252      1252   1252   1252      1252    1252  1252
# PG-13      2112   2112  2112      2112   2112   2112      2112    2112  2112
# R          3697   3697  3697      3695   3696   3696      3697    3697  3697
# TV-14         1      1     1         1      1      1         1       1     1
# TV-MA         9      9     9         9      9      9         9       9     9
# TV-PG         5      5     5         5      5      5         5       4     5
# Unrated      52     52    52        52     52     52        52      51    52
# ...

# %%
data.year.min()
# Out:
# 1980

# %%
data.year.max()
# Out:
# 2020

# %%
data[data.year == data.year.max()]
# Out:
#                            name     rating      genre  year  \
# 7643                      Tenet      PG-13     Action  2020
# 7644          Wonder Woman 1984      PG-13     Action  2020
# 7645              Birds of Prey          R     Action  2020
# 7646          The Invisible Man          R      Drama  2020
# 7647                     Onward         PG  Animation  2020
# 7648          Bad Boys for Life          R     Action  2020
# 7649         Sonic the Hedgehog         PG     Action  2020
# 7650                   Dolittle         PG  Adventure  2020
# 7651       The Call of the Wild         PG  Adventure  2020
# 7652          The Eight Hundred  Not Rated     Action  2020
# 7653                 The Quarry          R      Crime  2020
# 7654   Star Trek First Frontier        NaN     Sci-Fi  2020
# 7655      Legend of Deification      TV-PG  Animation  2020
# 7656                      Tulsa      PG-13     Comedy  2020
# 7657                       Leap        NaN      Drama  2020
# ...

# %%
pd.to_datetime(data.year)
# Out:
# 0      1970-01-01 00:00:00.000001980
# 1      1970-01-01 00:00:00.000001980
# 2      1970-01-01 00:00:00.000001980
# 3      1970-01-01 00:00:00.000001980
# 4      1970-01-01 00:00:00.000001980
#                     ...
# 7663   1970-01-01 00:00:00.000002020
# 7664   1970-01-01 00:00:00.000002020
# 7665   1970-01-01 00:00:00.000002020
# 7666   1970-01-01 00:00:00.000002020
# 7667   1970-01-01 00:00:00.000002020
# Name: year, Length: 7668, dtype: datetime64[ns]

# %%
data.year.dtype
# Out:
# dtype('int64')

# %%
data.year.astype(str)
# Out:
# 0       1980
# 1       1980
# 2       1980
# 3       1980
# 4       1980
#         ...
# 7663    2020
# 7664    2020
# 7665    2020
# 7666    2020
# 7667    2020
# Name: year, Length: 7668, dtype: object

# %% [markdown]
# # Setting

# %%
data.loc[:,'new'] = 'empty'

# %%
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
data.loc[:,'new'] = 1
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
data.loc[:,'new'] = data.budget/data.score
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# '''
# data.dropna()
# data.fillna(value=0)
# '''

# %% [markdown]
# data.loc['new'] = pd.mask(data.score>6, 'good', 'bad')
# data.head()

# %%
data.score = data.score.apply(lambda x: x*10)

# %%
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)   84.0   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)   58.0    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)   87.0  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)   77.0   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)   73.0   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# """
# aplly is done on row or column
# apllymap is over whole dataframe
# """

# %%
years = data.year.unique().tolist()
years
# Out:
# [1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020]

# %%
exchange = pd.DataFrame({'year':years,'exch':[x for x in range(len(years))]})

# %%
exchange
# Out:
#     year  exch
# 0   1980     0
# 1   1981     1
# 2   1982     2
# 3   1983     3
# 4   1984     4
# 5   1985     5
# 6   1986     6
# 7   1987     7
# 8   1988     8
# 9   1989     9
# 10  1990    10
# 11  1991    11
# 12  1992    12
# 13  1993    13
# 14  1994    14
# 15  1995    15
# 16  1996    16
# 17  1997    17
# 18  1998    18
# 19  1999    19
# 20  2000    20
# 21  2001    21
# 22  2002    22
# 23  2003    23
# 24  2004    24
# 25  2005    25
# 26  2006    26
# 27  2007    27
# 28  2008    28
# 29  2009    29
# 30  2010    30
# 31  2011    31
# 32  2012    32
# 33  2013    33
# 34  2014    34
# 35  2015    35
# 36  2016    36
# 37  2017    37
# 38  2018    38
# 39  2019    39
# 40  2020    40

# %%
data_exch = data.merge(exchange,how='left',on='year')
data_exch.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)   84.0   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)   58.0    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)   87.0  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)   77.0   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)   73.0   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
data_exch['new_test']=data_exch['budget']*data_exch['exch']

# %%
data_exch
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
"""
merge on = column to merge
how{‘left’, ‘right’, ‘outer’, ‘inner’, ‘cross’}, default ‘inner’

    Type of merge to be performed.

        left: use only keys from left frame, similar to a SQL left outer join; preserve key order.

        right: use only keys from right frame, similar to a SQL right outer join; preserve key order.

        outer: use union of keys from both frames, similar to a SQL full outer join; sort keys lexicographically.

        inner: use intersection of keys from both frames, similar to a SQL inner join; preserve the order of the left keys.

        cross: creates the cartesian product from both frames, preserves the order of the left keys.
"""
# Out:
# '\nmerge on = column to merge\nhow{‘left’, ‘right’, ‘outer’, ‘inner’, ‘cross’}, default ‘inner’\n\n    Type of merge to be performed.\n\n        left: use only keys from left frame, similar to a SQL left outer join; preserve key order.\n\n        right: use only keys from right frame, similar to a SQL right outer join; preserve key order.\n\n        outer: use union of keys from both frames, similar to a SQL full outer join; sort keys lexicographically.\n\n        inner: use intersection of keys from both frames, similar to a SQL inner join; preserve the order of the left keys.\n\n        cross: creates the cartesian product from both frames, preserves the order of the left keys.\n'

# %%
data_append=data.head().name

# %%
data_append
# Out:
# 0                                       The Shining
# 1                                   The Blue Lagoon
# 2    Star Wars: Episode V - The Empire Strikes Back
# 3                                         Airplane!
# 4                                        Caddyshack
# Name: name, dtype: object

# %%
data_append2=data_append.copy()
data_append.append(data_append2,ignore_index=True)
# Out:
# C:\Users\Petar\AppData\Local\Temp\ipykernel_17036\699343275.py:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data_append.append(data_append2,ignore_index=True)
# 0                                       The Shining
# 1                                   The Blue Lagoon
# 2    Star Wars: Episode V - The Empire Strikes Back
# 3                                         Airplane!
# 4                                        Caddyshack
# 5                                       The Shining
# 6                                   The Blue Lagoon
# 7    Star Wars: Episode V - The Empire Strikes Back
# 8                                         Airplane!
# 9                                        Caddyshack
# Name: name, dtype: object

# %%
pd.concat([data_append,data_append2])
# Out:
# 0                                       The Shining
# 1                                   The Blue Lagoon
# 2    Star Wars: Episode V - The Empire Strikes Back
# 3                                         Airplane!
# 4                                        Caddyshack
# 0                                       The Shining
# 1                                   The Blue Lagoon
# 2    Star Wars: Episode V - The Empire Strikes Back
# 3                                         Airplane!
# 4                                        Caddyshack
# Name: name, dtype: object
